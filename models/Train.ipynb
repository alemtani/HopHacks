# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.preprocessing import StandardScaler

# Import the dataset
df = pd.read_csv('phishing_websites.csv')

# Take out first column of IDs
df = df.iloc[:, 1:]

# The training data is categorical data that has already been preprocessed
# Each category indicates what that feature alone predicts about the website:
# Key: 1 = Phishing, 0 = Suspicious, -1 = Legitimate
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# Feature scaling
sc = StandardScaler()
X = sc.fit_transform(X)

# Build the ANN
ann = tf.keras.models.Sequential()

# Add input layer and three hidden layers
ann.add(tf.keras.layers.Dense(units=30, activation='relu'))
ann.add(tf.keras.layers.Dense(units=30, activation='relu'))
ann.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Add output layer
ann.add(tf.keras.layers.Dense(units=1))

# Compile the ANN
ann.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Train the ANN
ann.fit(X, y, batch_size = 32, epochs = 100)

# Save the ANN
ann.save('saved_model.pb')
# Out:
# 2021-09-18 10:52:37.473699: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-18 10:52:37.475200: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.
# Train on 11055 samples
# Epoch 1/100
# 11055/11055 [==============================] - 1s 133us/sample - loss: 0.3855
# Epoch 2/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.2194
# Epoch 3/100
# 11055/11055 [==============================] - 1s 58us/sample - loss: 0.1853
# Epoch 4/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.1653
# Epoch 5/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.1516
# Epoch 6/100
# 11055/11055 [==============================] - 1s 58us/sample - loss: 0.1409
# Epoch 7/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.1327
# Epoch 8/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.1253
# Epoch 9/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.1193
# Epoch 10/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.1131
# Epoch 11/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.1078
# Epoch 12/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.1032
# Epoch 13/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.1001
# Epoch 14/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.0949
# Epoch 15/100
# 11055/11055 [==============================] - 1s 68us/sample - loss: 0.0929
# Epoch 16/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0896
# Epoch 17/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0868
# Epoch 18/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0838
# Epoch 19/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0818
# Epoch 20/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.0793
# Epoch 21/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0787
# Epoch 22/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0742
# Epoch 23/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0734
# Epoch 24/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0724
# Epoch 25/100
# 11055/11055 [==============================] - 1s 65us/sample - loss: 0.0714
# Epoch 26/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0701
# Epoch 27/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0678
# Epoch 28/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0677
# Epoch 29/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0659
# Epoch 30/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0656
# Epoch 31/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0630
# Epoch 32/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0645
# Epoch 33/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0627
# Epoch 34/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0613
# Epoch 35/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0601
# Epoch 36/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0607
# Epoch 37/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0591
# Epoch 38/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0589
# Epoch 39/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0576
# Epoch 40/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0581
# Epoch 41/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0562
# Epoch 42/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0563
# Epoch 43/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0560
# Epoch 44/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0545
# Epoch 45/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0548
# Epoch 46/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0530
# Epoch 47/100
# 11055/11055 [==============================] - 1s 63us/sample - loss: 0.0522
# Epoch 48/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0539
# Epoch 49/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0523
# Epoch 50/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0523
# Epoch 51/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0530
# Epoch 52/100
# 11055/11055 [==============================] - 1s 63us/sample - loss: 0.0501
# Epoch 53/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0498
# Epoch 54/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0509
# Epoch 55/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0501
# Epoch 56/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0491
# Epoch 57/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0493
# Epoch 58/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0476
# Epoch 59/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0476
# Epoch 60/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0476
# Epoch 61/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0465
# Epoch 62/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0484
# Epoch 63/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0478
# Epoch 64/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0467
# Epoch 65/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0455
# Epoch 66/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0465
# Epoch 67/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0463
# Epoch 68/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0456
# Epoch 69/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0452
# Epoch 70/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0453
# Epoch 71/100
# 11055/11055 [==============================] - 1s 64us/sample - loss: 0.0463
# Epoch 72/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0445
# Epoch 73/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0452
# Epoch 74/100
# 11055/11055 [==============================] - 1s 64us/sample - loss: 0.0432
# Epoch 75/100
# 11055/11055 [==============================] - 1s 63us/sample - loss: 0.0440
# Epoch 76/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0440
# Epoch 77/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0454
# Epoch 78/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0440
# Epoch 79/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0430
# Epoch 80/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0432
# Epoch 81/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0416
# Epoch 82/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0427
# Epoch 83/100
# 11055/11055 [==============================] - 1s 64us/sample - loss: 0.0432
# Epoch 84/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0420
# Epoch 85/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0427
# Epoch 86/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0424
# Epoch 87/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0423
# Epoch 88/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0406
# Epoch 89/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0419
# Epoch 90/100
# 11055/11055 [==============================] - 1s 62us/sample - loss: 0.0423
# Epoch 91/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0416
# Epoch 92/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.0419
# Epoch 93/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0422
# Epoch 94/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.0423
# Epoch 95/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.0413
# Epoch 96/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0414
# Epoch 97/100
# 11055/11055 [==============================] - 1s 59us/sample - loss: 0.0409
# Epoch 98/100
# 11055/11055 [==============================] - 1s 61us/sample - loss: 0.0409
# Epoch 99/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0396
# Epoch 100/100
# 11055/11055 [==============================] - 1s 60us/sample - loss: 0.0406
# WARNING:tensorflow:From /Users/Alex1/opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2021-09-18 10:53:46.138275: W tensorflow/python/util/util.cc:299] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: saved_model.pb/assets

# %%
ann.predict([[1]*30])
# Out:
# array([[0.9680312]], dtype=float32)
